# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, date

base_url = 'https://api.energy-charts.info/'
country_code = 'ch'

def process_timestamps(unix_seconds):
    return [datetime.utcfromtimestamp(ts) for ts in unix_seconds]

def get_public_power():
    start_date = date(2010, 1, 1)
    end_date = date(2023, 12, 31)

    start_datetime = start_date.strftime('%Y-%m-%dT%H:%M:%S%z')
    end_datetime = end_date.strftime('%Y-%m-%dT%H:%M:%S%z')
    
    url = base_url + 'public_power'
    params = {
        'country': country_code,
        'start': start_datetime,
        'end': end_datetime
    }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        print(f"Failed to retrieve data: {response.status_code} - {response.text}")
        return pd.DataFrame()

    data = response.json()
    timestamps = process_timestamps(data['unix_seconds'])
    production_data = data['production_types']

    df_list = []
    for entry in production_data:
        if entry['name'] == 'Solar':
            df = pd.DataFrame({
                'Time': timestamps,
                'Production Type': entry['name'],
                'Power (MW)': entry['data']
            })
            df_list.append(df)

    if not df_list:
        return pd.DataFrame()

    return pd.concat(df_list, ignore_index=True)

# Load data
df = get_public_power()

df['Time'] = pd.to_datetime(df['Time'])
df.set_index('Time', inplace=True)
    

data = df['Power (MW)'].values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

print(df.head(25))
# Out:
#                     Production Type  Power (MW)
# Time
# 2015-01-01 00:00:00           Solar         0.2
# 2015-01-01 01:00:00           Solar         0.3
# 2015-01-01 02:00:00           Solar         0.4
# 2015-01-01 03:00:00           Solar         0.4
# 2015-01-01 04:00:00           Solar         0.4
# 2015-01-01 05:00:00           Solar         0.4
# 2015-01-01 06:00:00           Solar         0.4
# 2015-01-01 07:00:00           Solar         1.2
# 2015-01-01 08:00:00           Solar        11.0
# 2015-01-01 09:00:00           Solar        25.8
# 2015-01-01 10:00:00           Solar        42.5
# 2015-01-01 11:00:00           Solar        51.1
# 2015-01-01 12:00:00           Solar        52.6
# 2015-01-01 13:00:00           Solar        40.1
# 2015-01-01 14:00:00           Solar        20.7
# 2015-01-01 15:00:00           Solar         3.4
# 2015-01-01 16:00:00           Solar         0.3
# 2015-01-01 17:00:00           Solar         0.4
# 2015-01-01 18:00:00           Solar         0.4
# 2015-01-01 19:00:00           Solar         0.4
# 2015-01-01 20:00:00           Solar         0.4
# 2015-01-01 21:00:00           Solar         0.4
# 2015-01-01 22:00:00           Solar         0.4
# 2015-01-01 23:00:00           Solar         0.4
# 2015-01-02 00:00:00           Solar         0.4

# %%
df = df.dropna(how='any')
print(df.head(25))
# Out:
#                     Production Type  Power (MW)
# Time
# 2015-01-01 00:00:00           Solar         0.2
# 2015-01-01 01:00:00           Solar         0.3
# 2015-01-01 02:00:00           Solar         0.4
# 2015-01-01 03:00:00           Solar         0.4
# 2015-01-01 04:00:00           Solar         0.4
# 2015-01-01 05:00:00           Solar         0.4
# 2015-01-01 06:00:00           Solar         0.4
# 2015-01-01 07:00:00           Solar         1.2
# 2015-01-01 08:00:00           Solar        11.0
# 2015-01-01 09:00:00           Solar        25.8
# 2015-01-01 10:00:00           Solar        42.5
# 2015-01-01 11:00:00           Solar        51.1
# 2015-01-01 12:00:00           Solar        52.6
# 2015-01-01 13:00:00           Solar        40.1
# 2015-01-01 14:00:00           Solar        20.7
# 2015-01-01 15:00:00           Solar         3.4
# 2015-01-01 16:00:00           Solar         0.3
# 2015-01-01 17:00:00           Solar         0.4
# 2015-01-01 18:00:00           Solar         0.4
# 2015-01-01 19:00:00           Solar         0.4
# 2015-01-01 20:00:00           Solar         0.4
# 2015-01-01 21:00:00           Solar         0.4
# 2015-01-01 22:00:00           Solar         0.4
# 2015-01-01 23:00:00           Solar         0.4
# 2015-01-02 00:00:00           Solar         0.4

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def create_dataset(data, look_back=1):
    """
    Convert an array of values into a dataset matrix suitable for LSTM training.
    
    Parameters:
        data (array): The dataset array containing sequential data.
        look_back (int): Number of previous time steps to use as input variables to predict the next time period.
        
    Returns:
        X (array): Feature dataset.
        y (array): Labels.
    """
    X, y = [], []
    for i in range(len(data) - look_back):
        a = data[i:(i + look_back), 0]  # Fetch the input data from the current index to the look_back length
        X.append(a)
        y.append(data[i + look_back, 0])  # The label will be the next data point
    return np.array(X), np.array(y)

# Assume 'data' is loaded and scaled as the 'Power (MW)' from your solar data.
# For example purposes, let's define 'data' here manually:
data = np.array([[i] for i in range(100)])  # Example data generation
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# Define the look_back period
look_back = 24  # This means the input for each sample will be sequences of 3 past observations

# Create the dataset
X, y = create_dataset(data, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

print("Sample of feature (X) and label (y):")
print("X[0]:", X[0])
print("y[0]:", y[0])
# Out:
# Sample of feature (X) and label (y):
# X[0]: [[0.        ]
#  [0.01010101]
#  [0.02020202]
#  [0.03030303]
#  [0.04040404]
#  [0.05050505]
#  [0.06060606]
#  [0.07070707]
#  [0.08080808]
#  [0.09090909]
#  [0.1010101 ]
#  [0.11111111]
#  [0.12121212]
#  [0.13131313]
#  [0.14141414]
#  [0.15151515]
#  [0.16161616]
#  [0.17171717]
#  [0.18181818]
#  [0.19191919]
#  [0.2020202 ]
#  [0.21212121]
#  [0.22222222]
#  [0.23232323]]
# y[0]: 0.24242424242424243

# %%
model = Sequential([
     LSTM(60, input_shape=(look_back, 1)),
     Dense(1)
])


optimizer = Adam(learning_rate=0.01) 
model.compile(optimizer=optimizer, loss='mean_squared_error')
#early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(X, y, epochs=200, batch_size=16, validation_split=0.2, verbose=1)

model.summary()
# Out:
# Epoch 1/200
# /Users/yazdanmusa/Dev/dviz-final-project/venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.2141 - val_loss: 0.0984
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0343 - val_loss: 0.0865
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0177 - val_loss: 8.5643e-04
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0119 - val_loss: 0.0447
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0090 - val_loss: 0.0440
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0060 - val_loss: 0.0093
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - val_loss: 0.0049
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0178
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0141
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9876e-04 - val_loss: 0.0035
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6635e-04 - val_loss: 4.0012e-04
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2038e-04 - val_loss: 6.9641e-05
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8597e-04 - val_loss: 6.3783e-05
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5867e-04 - val_loss: 3.4566e-04
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0566e-04 - val_loss: 4.1813e-04
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0475e-04 - val_loss: 9.6358e-06
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.2623e-05 - val_loss: 3.3864e-04
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0335e-05 - val_loss: 4.4790e-04
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8003e-05 - val_loss: 6.6446e-05
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9265e-05 - val_loss: 3.4427e-04
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7504e-05 - val_loss: 4.4702e-05
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.9159e-06 - val_loss: 3.7787e-05
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1566e-06 - val_loss: 5.6610e-05
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4108e-06 - val_loss: 4.9316e-06
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1536e-06 - val_loss: 8.0667e-05
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.2186e-06 - val_loss: 1.8099e-05
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5431e-06 - val_loss: 1.0075e-04
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9639e-06 - val_loss: 5.0162e-05
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7911e-06 - val_loss: 8.2980e-05
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2589e-06 - val_loss: 6.9428e-05
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1531e-06 - val_loss: 4.4411e-05
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8190e-07 - val_loss: 5.2046e-05
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1646e-06 - val_loss: 3.7560e-05
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6224e-07 - val_loss: 4.2726e-05
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.3195e-07 - val_loss: 3.6219e-05
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7323e-07 - val_loss: 4.7914e-05
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0528e-07 - val_loss: 4.0340e-05
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3269e-07 - val_loss: 4.3510e-05
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1791e-07 - val_loss: 4.2513e-05
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9827e-07 - val_loss: 3.7751e-05
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.2868e-07 - val_loss: 3.9962e-05
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4619e-07 - val_loss: 3.2585e-05
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0782e-07 - val_loss: 3.8721e-05
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.2217e-07 - val_loss: 3.3955e-05
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3603e-07 - val_loss: 3.5124e-05
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5088e-07 - val_loss: 3.7342e-05
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5784e-07 - val_loss: 3.0126e-05
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4463e-07 - val_loss: 3.7244e-05
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8988e-07 - val_loss: 2.9363e-05
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8376e-07 - val_loss: 3.3429e-05
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6316e-07 - val_loss: 2.7946e-05
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2498e-07 - val_loss: 3.0987e-05
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4513e-07 - val_loss: 2.5338e-05
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9789e-07 - val_loss: 3.1714e-05
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0478e-07 - val_loss: 2.6046e-05
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7722e-07 - val_loss: 2.7077e-05
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7202e-07 - val_loss: 2.5411e-05
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8980e-07 - val_loss: 3.0472e-05
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9127e-07 - val_loss: 2.0662e-05
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2236e-07 - val_loss: 2.8853e-05
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1328e-07 - val_loss: 2.2115e-05
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4566e-07 - val_loss: 2.4566e-05
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2937e-07 - val_loss: 2.1947e-05
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5148e-07 - val_loss: 2.3520e-05
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2730e-07 - val_loss: 2.2702e-05
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0389e-07 - val_loss: 2.1032e-05
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7639e-07 - val_loss: 2.4891e-05
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9029e-07 - val_loss: 1.8099e-05
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2775e-07 - val_loss: 2.6087e-05
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6044e-07 - val_loss: 1.5154e-05
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9407e-07 - val_loss: 2.4497e-05
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5390e-07 - val_loss: 1.5734e-05
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8959e-07 - val_loss: 2.2798e-05
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4739e-07 - val_loss: 1.4973e-05
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1755e-07 - val_loss: 1.7446e-05
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7389e-07 - val_loss: 1.7680e-05
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2493e-07 - val_loss: 1.6061e-05
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9349e-07 - val_loss: 2.1366e-05
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7206e-07 - val_loss: 1.7951e-05
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3513e-07 - val_loss: 1.7801e-05
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3534e-07 - val_loss: 1.7896e-05
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5298e-07 - val_loss: 1.8250e-05
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5533e-07 - val_loss: 1.5850e-05
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4150e-07 - val_loss: 1.5192e-05
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3168e-07 - val_loss: 1.9056e-05
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5710e-07 - val_loss: 1.2776e-05
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8845e-07 - val_loss: 1.8323e-05
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8816e-07 - val_loss: 1.5025e-05
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1593e-07 - val_loss: 1.2971e-05
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7831e-07 - val_loss: 1.9414e-05
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7737e-07 - val_loss: 1.2353e-05
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1156e-07 - val_loss: 1.5375e-05
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7274e-07 - val_loss: 1.8981e-05
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0506e-07 - val_loss: 1.0142e-05
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5104e-07 - val_loss: 1.6593e-05
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2710e-07 - val_loss: 1.3238e-05
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2382e-07 - val_loss: 1.3097e-05
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2439e-07 - val_loss: 1.4691e-05
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0647e-07 - val_loss: 1.1663e-05
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0924e-07 - val_loss: 1.7739e-05
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6352e-07 - val_loss: 1.2833e-05
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3425e-07 - val_loss: 1.0270e-05
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3440e-07 - val_loss: 1.2870e-05
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3663e-07 - val_loss: 1.3121e-05
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1215e-07 - val_loss: 1.2484e-05
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3184e-07 - val_loss: 1.1108e-05
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1985e-07 - val_loss: 1.4948e-05
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6421e-07 - val_loss: 1.3914e-05
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1000e-07 - val_loss: 9.0964e-06
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9039e-07 - val_loss: 1.3879e-05
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9464e-07 - val_loss: 1.4724e-05
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1308e-07 - val_loss: 9.2105e-06
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9809e-07 - val_loss: 1.4037e-05
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9270e-07 - val_loss: 1.6247e-05
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8490e-07 - val_loss: 7.2476e-06
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7924e-07 - val_loss: 1.2146e-05
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6691e-07 - val_loss: 1.6252e-05
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1176e-07 - val_loss: 1.0586e-05
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0536e-07 - val_loss: 1.3609e-05
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0667e-07 - val_loss: 1.2072e-05
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2602e-08 - val_loss: 9.6882e-06
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2247e-07 - val_loss: 1.4601e-05
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1095e-07 - val_loss: 1.1821e-05
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2957e-07 - val_loss: 8.0948e-06
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7594e-07 - val_loss: 1.3154e-05
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1920e-07 - val_loss: 1.3948e-05
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5288e-07 - val_loss: 8.5882e-06
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1213e-07 - val_loss: 1.2785e-05
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1621e-07 - val_loss: 1.3064e-05
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3181e-07 - val_loss: 9.4226e-06
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1563e-07 - val_loss: 1.3308e-05
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5053e-07 - val_loss: 1.3643e-05
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2981e-07 - val_loss: 8.9327e-06
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0718e-07 - val_loss: 1.0569e-05
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5019e-07 - val_loss: 1.3667e-05
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5609e-07 - val_loss: 8.6092e-06
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8487e-07 - val_loss: 8.3873e-06
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2869e-07 - val_loss: 1.3389e-05
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2742e-07 - val_loss: 9.6595e-06
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2341e-07 - val_loss: 1.1457e-05
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4382e-08 - val_loss: 1.1301e-05
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1121e-07 - val_loss: 1.1222e-05
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0272e-07 - val_loss: 1.2182e-05
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0074e-07 - val_loss: 1.0176e-05
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0512e-07 - val_loss: 1.3305e-05
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8149e-07 - val_loss: 1.3874e-05
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3280e-07 - val_loss: 7.8365e-06
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3859e-07 - val_loss: 1.2189e-05
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8324e-07 - val_loss: 1.5435e-05
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0715e-07 - val_loss: 1.0657e-05
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.7611e-08 - val_loss: 1.1967e-05
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4423e-07 - val_loss: 1.3722e-05
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3279e-07 - val_loss: 1.1280e-05
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6229e-07 - val_loss: 8.3192e-06
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3784e-07 - val_loss: 1.2122e-05
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5668e-07 - val_loss: 1.3790e-05
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5375e-07 - val_loss: 1.0717e-05
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.2310e-08 - val_loss: 1.0630e-05
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.7860e-08 - val_loss: 1.2446e-05
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0873e-07 - val_loss: 1.0235e-05
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1342e-07 - val_loss: 9.7908e-06
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2377e-07 - val_loss: 1.1842e-05
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0201e-07 - val_loss: 9.4129e-06
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3011e-07 - val_loss: 1.0161e-05
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1848e-08 - val_loss: 1.1182e-05
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5538e-08 - val_loss: 9.8408e-06
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3122e-07 - val_loss: 1.0537e-05
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2469e-07 - val_loss: 1.3263e-05
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6008e-07 - val_loss: 1.1527e-05
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1484e-07 - val_loss: 1.0228e-05
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0580e-07 - val_loss: 9.2589e-06
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2976e-07 - val_loss: 1.2519e-05
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3159e-07 - val_loss: 1.3453e-05
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1958e-07 - val_loss: 1.0376e-05
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0577e-07 - val_loss: 1.2602e-05
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6494e-07 - val_loss: 8.5724e-06
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8465e-07 - val_loss: 8.9702e-06
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2832e-07 - val_loss: 9.9947e-06
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1135e-07 - val_loss: 1.1284e-05
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.7775e-08 - val_loss: 1.2804e-05
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6020e-07 - val_loss: 9.4840e-06
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1689e-07 - val_loss: 9.5755e-06
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0864e-07 - val_loss: 1.0104e-05
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3264e-07 - val_loss: 1.2691e-05
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4061e-07 - val_loss: 1.2204e-05
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8117e-07 - val_loss: 1.1146e-05
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4597e-07 - val_loss: 8.9159e-06
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7361e-07 - val_loss: 5.8545e-06
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9405e-07 - val_loss: 6.6739e-06
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8364e-07 - val_loss: 1.6098e-05
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7021e-07 - val_loss: 1.8534e-05
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8171e-07 - val_loss: 9.6481e-06
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0089e-07 - val_loss: 4.3079e-06
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0711e-07 - val_loss: 5.8872e-06
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1795e-07 - val_loss: 1.2197e-05
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7944e-07 - val_loss: 1.8804e-05
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9445e-07 - val_loss: 1.3403e-05
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7686e-07 - val_loss: 1.0689e-05
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 60)             │        14,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            61 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,825 (175.10 KB)
#  Trainable params: 14,941 (58.36 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 29,884 (116.74 KB)

# %%
# Plot training loss and validation loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
predictions = model.predict(X)

predictions = scaler.inverse_transform(predictions)
actuals = scaler.inverse_transform([y])

rmse = np.sqrt(mean_squared_error(actuals[0], predictions[:,0]))
mape = np.mean(np.abs((actuals[0] - predictions[:,0]) / actuals[0])) * 100
r_squared = 1 - (np.sum((actuals[0] - predictions[:,0])**2) / np.sum((actuals[0] - np.mean(actuals[0]))**2))
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}')
print(f'R^2: {r_squared}')

model.save('solar_power_lstm.keras')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE: 0.15106081514363662
# MAPE: 0.1100903841908631
# R^2: 0.999952583127539

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import load_model

# Load your trained model
model = load_model('solar_power_lstm.keras')  # Update the path to where your model is saved

# Scale and prepare the last 24 hours of data
recent_data_scaled = scaler.transform(df['Power (MW)'].tail(24).values.reshape(-1, 1))
recent_data_scaled = recent_data_scaled.reshape(1, 24, 1)

predictions = []
current_batch = recent_data_scaled

# Predict iteratively
for i in range(24):  # Predict the next 24 hours
    current_pred = model.predict(current_batch)[0]  # Predict the next hour
    predictions.append(current_pred)  # Store the prediction
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis=1)  # Update the batch to include the new prediction

# Inverse scale predictions
predicted_original = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

# Print or store the predictions
predicted_times = pd.date_range(start=date(2024,4,23), periods=24, freq='H')
predicted_df = pd.DataFrame(data=predicted_original.flatten(), index=predicted_times, columns=['Predicted Power (MW)'])
print(predicted_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#                      Predicted Power (MW)
# 2024-04-23 00:00:00             18.153614
# 2024-04-23 01:00:00             14.169910
# 2024-04-23 02:00:00             12.775808
# 2024-04-23 03:00:00             12.440391
# 2024-04-23 04:00:00             12.543378
# 2024-04-23 05:00:00             12.865909
# 2024-04-23 06:00:00             13.349577
# 2024-04-23 07:00:00             13.981273
# 2024-04-23 08:00:00             14.750710
# 2024-04-23 09:00:00             15.674743
# 2024-04-23 10:00:00             16.739925
# 2024-04-23 11:00:00             17.857267
# 2024-04-23 12:00:00             18.957197
# 2024-04-23 13:00:00             20.011326
# 2024-04-23 14:00:00             21.037178
# 2024-04-23 15:00:00             22.042376
# 2024-04-23 16:00:00             23.038197
# 2024-04-23 17:00:00             24.037888
# 2024-04-23 18:00:00             25.038355
# 2024-04-23 19:00:00             26.038733
# 2024-04-23 20:00:00             27.038866
# 2024-04-23 21:00:00             28.038713
# 2024-04-23 22:00:00             29.038187
# 2024-04-23 23:00:00             30.037199
# /var/folders/4n/cyw2bn_96cv6fhpjgbhbl1wc0000gn/T/ipykernel_48059/3256585944.py:25: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   predicted_times = pd.date_range(start=date(2024,4,23), periods=24, freq='H')
